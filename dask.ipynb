# %% [markdown]
# # Dask

# %%
# %matplotlib inline

# %%
from dask.diagnostics import ProgressBar

# %%
progress_bar = ProgressBar()
progress_bar.register()

# %%
import dask.dataframe as dd

# %%
df = dd.demo.make_timeseries(start='2014', end='2015', dtypes={'A': float, 'B': int},
                             freq='5s', partition_freq='3M', seed=1234)

# %%
df.A.cumsum().resample('1w').mean().compute().plot();
# Out:
# [                                        ] | 0% Completed |  0.2s
# /srv/conda/lib/python3.7/site-packages/dask/dataframe/utils.py:391: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.
#   tz=idx.tz, name=idx.name)
# [########################################] | 100% Completed |  9.1s
